# %%
import polars as pl

# %%
reverse_coding_items = pl.read_csv("./data/ReverseCodingItems.csv", eol_char="\r")

# %%
reverse_coding_items
# Out:
# shape: (44, 5)
# ┌─────────────────────────────┬───────────┬──────────────────┬───────────────────────┬─────────────┐
# │ Question                    ┆ Construct ┆ Question # on    ┆ Needs Reverse Coding? ┆ Column Name │
# │ ---                         ┆ ---       ┆ Qualtrics Survey ┆ ---                   ┆ ---         │
# │ str                         ┆ i64       ┆ ---              ┆ str                   ┆ str         │
# │                             ┆           ┆ i64              ┆                       ┆             │
# ╞═════════════════════════════╪═══════════╪══════════════════╪═══════════════════════╪═════════════╡
# │ In the future, I plan to    ┆ 1         ┆ 1                ┆ No                    ┆ F1          │
# │ parti…                      ┆           ┆                  ┆                       ┆             │
# │ Individuals are responsible ┆ 5         ┆ 2                ┆ Yes                   ┆ F5          │
# │ fo…                         ┆           ┆                  ┆                       ┆             │
# │ When tryng to understand    ┆ 2         ┆ 3                ┆ No                    ┆ F2          │
# │ the p…                      ┆           ┆                  ┆                       ┆             │
# │ I plan to become involved   ┆ 1         ┆ 4                ┆ No                    ┆ F1.1        │
# │ in m…                       ┆           ┆                  ┆                       ┆             │
# │ I can communicate well with ┆ 2         ┆ 5                ┆ No                    ┆ F2.1        │
# │ ot…                         ┆           ┆                  ┆                       ┆             │
# │ …                           ┆ …         ┆ …                ┆ …                     ┆ …           │
# │ I prefer the company of     ┆ 6         ┆ 40               ┆ Yes                   ┆ F6.4        │
# │ people…                     ┆           ┆                  ┆                       ┆             │
# │ I have the ability to lead  ┆ 4         ┆ 41               ┆ No                    ┆ F4.4        │
# │ a g…                        ┆           ┆                  ┆                       ┆             │
# │ It is important to me that  ┆ 5         ┆ 42               ┆ No                    ┆ F5.7        │
# │ equ…                        ┆           ┆                  ┆                       ┆             │
# │ I plan to be involved in    ┆ 3         ┆ 43               ┆ No                    ┆ F3.5        │
# │ the p…                      ┆           ┆                  ┆                       ┆             │
# │ I can successfully resolve  ┆ 2         ┆ 44               ┆ No                    ┆ F2.11       │
# │ con…                        ┆           ┆                  ┆                       ┆             │
# └─────────────────────────────┴───────────┴──────────────────┴───────────────────────┴─────────────┘

# %%
health_survey = pl.read_csv("./data/health_survey.csv")

# %%
health_survey
# Out:
# shape: (264, 45)
# ┌─────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ ID  ┆ F1         ┆ F5         ┆ F2         ┆ … ┆ F4.4       ┆ F5.7       ┆ F3.5      ┆ F2.11     │
# │ --- ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │ i64 ┆ str        ┆ str        ┆ str        ┆   ┆ str        ┆ str        ┆ str       ┆ str       │
# ╞═════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 1   ┆ Somewhat   ┆ Somewhat   ┆ Somewhat   ┆ … ┆ Somewhat   ┆ Somewhat   ┆ Somewhat  ┆ Somewhat  │
# │     ┆ Agree      ┆ Disagree   ┆ Agree      ┆   ┆ Agree      ┆ Agree      ┆ Agree     ┆ Agree     │
# │ 2   ┆ Somewhat   ┆ Somewhat   ┆ Somewhat   ┆ … ┆ Neither    ┆ Somewhat   ┆ Neither   ┆ Somewhat  │
# │     ┆ Agree      ┆ Disagree   ┆ Agree      ┆   ┆ Agree nor  ┆ Agree      ┆ Agree nor ┆ Agree     │
# │     ┆            ┆            ┆            ┆   ┆ Disagree   ┆            ┆ Disagree  ┆           │
# │ 3   ┆ Strongly   ┆ Neither    ┆ Somewhat   ┆ … ┆ Somewhat   ┆ Strongly   ┆ Strongly  ┆ Somewhat  │
# │     ┆ Agree      ┆ Agree nor  ┆ Agree      ┆   ┆ Agree      ┆ Agree      ┆ Disagree  ┆ Agree     │
# │     ┆            ┆ Disagree   ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 4   ┆ Somewhat   ┆ Somewhat   ┆ Strongly   ┆ … ┆ Neither    ┆ Somewhat   ┆ Somewhat  ┆ Somewhat  │
# │     ┆ Agree      ┆ Agree      ┆ Agree      ┆   ┆ Agree nor  ┆ Agree      ┆ Disagree  ┆ Agree     │
# │     ┆            ┆            ┆            ┆   ┆ Disagree   ┆            ┆           ┆           │
# │ 5   ┆ Strongly   ┆ Strongly   ┆ Neither    ┆ … ┆ Somewhat   ┆ Strongly   ┆ Somewhat  ┆ Somewhat  │
# │     ┆ Agree      ┆ Disagree   ┆ Agree nor  ┆   ┆ Agree      ┆ Agree      ┆ Disagree  ┆ Agree     │
# │     ┆            ┆            ┆ Disagree   ┆   ┆            ┆            ┆           ┆           │
# │ …   ┆ …          ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ 260 ┆ Somewhat   ┆ Somewhat   ┆ Somewhat   ┆ … ┆ Somewhat   ┆ Somewhat   ┆ Somewhat  ┆ Neither   │
# │     ┆ Agree      ┆ Disagree   ┆ Agree      ┆   ┆ Agree      ┆ Agree      ┆ Agree     ┆ Agree nor │
# │     ┆            ┆            ┆            ┆   ┆            ┆            ┆           ┆ Disagree  │
# │ 261 ┆ Somewhat   ┆ Somewhat   ┆ Strongly   ┆ … ┆ Somewhat   ┆ Somewhat   ┆ Somewhat  ┆ Somewhat  │
# │     ┆ Agree      ┆ Agree      ┆ Agree      ┆   ┆ Agree      ┆ Agree      ┆ Agree     ┆ Agree     │
# │ 262 ┆ Somewhat   ┆ Neither    ┆ Somewhat   ┆ … ┆ Strongly   ┆ Neither    ┆ Neither   ┆ Somewhat  │
# │     ┆ Agree      ┆ Agree nor  ┆ Agree      ┆   ┆ Agree      ┆ Agree nor  ┆ Agree nor ┆ Agree     │
# │     ┆            ┆ Disagree   ┆            ┆   ┆            ┆ Disagree   ┆ Disagree  ┆           │
# │ 263 ┆ Strongly   ┆ Somewhat   ┆ Strongly   ┆ … ┆ Somewhat   ┆ Strongly   ┆ Somewhat  ┆ Somewhat  │
# │     ┆ Agree      ┆ Disagree   ┆ Agree      ┆   ┆ Agree      ┆ Agree      ┆ Disagree  ┆ Agree     │
# │ 264 ┆ Somewhat   ┆ Strongly   ┆ Strongly   ┆ … ┆ Somewhat   ┆ Strongly   ┆ Strongly  ┆ Somewhat  │
# │     ┆ Agree      ┆ Disagree   ┆ Agree      ┆   ┆ Agree      ┆ Agree      ┆ Disagree  ┆ Agree     │
# └─────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
stack = (
    health_survey
    .melt(id_vars="ID")
    .rename({"ID": "Participant", "variable": "Question", "value": "Response"})
)
# Out:
# /var/folders/c3/sknssyls2hg49dyx6wsvjz9c0000gn/T/ipykernel_76680/1282397053.py:3: DeprecationWarning: `DataFrame.melt` is deprecated; use `DataFrame.unpivot` instead, with `index` instead of `id_vars` and `on` instead of `value_vars`
#   .melt(id_vars="ID")

# %%
stack
# Out:
# shape: (11_616, 3)
# ┌─────────────┬──────────┬────────────────────────────┐
# │ Participant ┆ Question ┆ Response                   │
# │ ---         ┆ ---      ┆ ---                        │
# │ i64         ┆ str      ┆ str                        │
# ╞═════════════╪══════════╪════════════════════════════╡
# │ 1           ┆ F1       ┆ Somewhat Agree             │
# │ 2           ┆ F1       ┆ Somewhat Agree             │
# │ 3           ┆ F1       ┆ Strongly Agree             │
# │ 4           ┆ F1       ┆ Somewhat Agree             │
# │ 5           ┆ F1       ┆ Strongly Agree             │
# │ …           ┆ …        ┆ …                          │
# │ 260         ┆ F2.11    ┆ Neither Agree nor Disagree │
# │ 261         ┆ F2.11    ┆ Somewhat Agree             │
# │ 262         ┆ F2.11    ┆ Somewhat Agree             │
# │ 263         ┆ F2.11    ┆ Somewhat Agree             │
# │ 264         ┆ F2.11    ┆ Somewhat Agree             │
# └─────────────┴──────────┴────────────────────────────┘

# %%
reverse_map = reverse_coding_items.select([
    pl.col("Construct").cast(pl.Utf8).alias("Question"),
    pl.col("Needs Reverse Coding?").alias("Needs Reverse"),
])
stack = stack.with_columns(pl.col("Question").cast(pl.Utf8))
stack = stack.join(reverse_map, on = "Question", how = "left")
stack = stack.with_columns(pl.col("Needs Reverse").fill_null("No"))

# %%
stack
# Out:
# shape: (11_616, 4)
# ┌─────────────┬──────────┬────────────────────────────┬───────────────┐
# │ Participant ┆ Question ┆ Response                   ┆ Needs Reverse │
# │ ---         ┆ ---      ┆ ---                        ┆ ---           │
# │ i64         ┆ str      ┆ str                        ┆ str           │
# ╞═════════════╪══════════╪════════════════════════════╪═══════════════╡
# │ 1           ┆ F1       ┆ Somewhat Agree             ┆ No            │
# │ 2           ┆ F1       ┆ Somewhat Agree             ┆ No            │
# │ 3           ┆ F1       ┆ Strongly Agree             ┆ No            │
# │ 4           ┆ F1       ┆ Somewhat Agree             ┆ No            │
# │ 5           ┆ F1       ┆ Strongly Agree             ┆ No            │
# │ …           ┆ …        ┆ …                          ┆ …             │
# │ 260         ┆ F2.11    ┆ Neither Agree nor Disagree ┆ No            │
# │ 261         ┆ F2.11    ┆ Somewhat Agree             ┆ No            │
# │ 262         ┆ F2.11    ┆ Somewhat Agree             ┆ No            │
# │ 263         ┆ F2.11    ┆ Somewhat Agree             ┆ No            │
# │ 264         ┆ F2.11    ┆ Somewhat Agree             ┆ No            │
# └─────────────┴──────────┴────────────────────────────┴───────────────┘

# %%
responses = {
    "Strongly Disagree": 1,
    "Somewhat Disagree": 2,
    "Neither Agree nor Disagree": 3,
    "Somewhat Agree": 4,
    "Strongly Agree": 5
}

# %%
stack = stack.with_columns(
    pl.col("Response").replace(responses)
    .cast(pl.Int64).alias("TempRecodeValue")
)

# %%
stack
# Out:
# shape: (11_616, 5)
# ┌─────────────┬──────────┬────────────────────────────┬───────────────┬─────────────────┐
# │ Participant ┆ Question ┆ Response                   ┆ Needs Reverse ┆ TempRecodeValue │
# │ ---         ┆ ---      ┆ ---                        ┆ ---           ┆ ---             │
# │ i64         ┆ str      ┆ str                        ┆ str           ┆ i64             │
# ╞═════════════╪══════════╪════════════════════════════╪═══════════════╪═════════════════╡
# │ 1           ┆ F1       ┆ Somewhat Agree             ┆ No            ┆ 4               │
# │ 2           ┆ F1       ┆ Somewhat Agree             ┆ No            ┆ 4               │
# │ 3           ┆ F1       ┆ Strongly Agree             ┆ No            ┆ 5               │
# │ 4           ┆ F1       ┆ Somewhat Agree             ┆ No            ┆ 4               │
# │ 5           ┆ F1       ┆ Strongly Agree             ┆ No            ┆ 5               │
# │ …           ┆ …        ┆ …                          ┆ …             ┆ …               │
# │ 260         ┆ F2.11    ┆ Neither Agree nor Disagree ┆ No            ┆ 3               │
# │ 261         ┆ F2.11    ┆ Somewhat Agree             ┆ No            ┆ 4               │
# │ 262         ┆ F2.11    ┆ Somewhat Agree             ┆ No            ┆ 4               │
# │ 263         ┆ F2.11    ┆ Somewhat Agree             ┆ No            ┆ 4               │
# │ 264         ┆ F2.11    ┆ Somewhat Agree             ┆ No            ┆ 4               │
# └─────────────┴──────────┴────────────────────────────┴───────────────┴─────────────────┘

# %%
reverse_scale = {1: 5, 2: 4, 3: 3, 4: 2, 5: 1}
stack = stack.with_columns(
    pl.when(pl.col("Needs Reverse") == "Yes")
    .then(pl.col("TempRecodeValue").replace(reverse_scale))
    .otherwise(pl.col("TempRecodeValue"))
    .alias("TempReverseValue")
)

# %%
stack
# Out:
# shape: (11_616, 6)
# ┌─────────────┬──────────┬────────────────────┬───────────────┬─────────────────┬──────────────────┐
# │ Participant ┆ Question ┆ Response           ┆ Needs Reverse ┆ TempRecodeValue ┆ TempReverseValue │
# │ ---         ┆ ---      ┆ ---                ┆ ---           ┆ ---             ┆ ---              │
# │ i64         ┆ str      ┆ str                ┆ str           ┆ i64             ┆ i64              │
# ╞═════════════╪══════════╪════════════════════╪═══════════════╪═════════════════╪══════════════════╡
# │ 1           ┆ F1       ┆ Somewhat Agree     ┆ No            ┆ 4               ┆ 4                │
# │ 2           ┆ F1       ┆ Somewhat Agree     ┆ No            ┆ 4               ┆ 4                │
# │ 3           ┆ F1       ┆ Strongly Agree     ┆ No            ┆ 5               ┆ 5                │
# │ 4           ┆ F1       ┆ Somewhat Agree     ┆ No            ┆ 4               ┆ 4                │
# │ 5           ┆ F1       ┆ Strongly Agree     ┆ No            ┆ 5               ┆ 5                │
# │ …           ┆ …        ┆ …                  ┆ …             ┆ …               ┆ …                │
# │ 260         ┆ F2.11    ┆ Neither Agree nor  ┆ No            ┆ 3               ┆ 3                │
# │             ┆          ┆ Disagree           ┆               ┆                 ┆                  │
# │ 261         ┆ F2.11    ┆ Somewhat Agree     ┆ No            ┆ 4               ┆ 4                │
# │ 262         ┆ F2.11    ┆ Somewhat Agree     ┆ No            ┆ 4               ┆ 4                │
# │ 263         ┆ F2.11    ┆ Somewhat Agree     ┆ No            ┆ 4               ┆ 4                │
# │ 264         ┆ F2.11    ┆ Somewhat Agree     ┆ No            ┆ 4               ┆ 4                │
# └─────────────┴──────────┴────────────────────┴───────────────┴─────────────────┴──────────────────┘

# %%
stack = stack.with_columns(
    pl.when(pl.col("Needs Reverse") == "Yes")
    .then(pl.col("TempRecodeValue"))
    .otherwise(pl.col("TempRecodeValue"))
    .alias("Recoded Value")
)

# %%
stack
# Out:
# shape: (11_616, 7)
# ┌─────────────┬──────────┬───────────────┬─────────┬───────────────┬───────────────┬───────────────┐
# │ Participant ┆ Question ┆ Response      ┆ Needs   ┆ TempRecodeVal ┆ TempReverseVa ┆ Recoded Value │
# │ ---         ┆ ---      ┆ ---           ┆ Reverse ┆ ue            ┆ lue           ┆ ---           │
# │ i64         ┆ str      ┆ str           ┆ ---     ┆ ---           ┆ ---           ┆ i64           │
# │             ┆          ┆               ┆ str     ┆ i64           ┆ i64           ┆               │
# ╞═════════════╪══════════╪═══════════════╪═════════╪═══════════════╪═══════════════╪═══════════════╡
# │ 1           ┆ F1       ┆ Somewhat      ┆ No      ┆ 4             ┆ 4             ┆ 4             │
# │             ┆          ┆ Agree         ┆         ┆               ┆               ┆               │
# │ 2           ┆ F1       ┆ Somewhat      ┆ No      ┆ 4             ┆ 4             ┆ 4             │
# │             ┆          ┆ Agree         ┆         ┆               ┆               ┆               │
# │ 3           ┆ F1       ┆ Strongly      ┆ No      ┆ 5             ┆ 5             ┆ 5             │
# │             ┆          ┆ Agree         ┆         ┆               ┆               ┆               │
# │ 4           ┆ F1       ┆ Somewhat      ┆ No      ┆ 4             ┆ 4             ┆ 4             │
# │             ┆          ┆ Agree         ┆         ┆               ┆               ┆               │
# │ 5           ┆ F1       ┆ Strongly      ┆ No      ┆ 5             ┆ 5             ┆ 5             │
# │             ┆          ┆ Agree         ┆         ┆               ┆               ┆               │
# │ …           ┆ …        ┆ …             ┆ …       ┆ …             ┆ …             ┆ …             │
# │ 260         ┆ F2.11    ┆ Neither Agree ┆ No      ┆ 3             ┆ 3             ┆ 3             │
# │             ┆          ┆ nor Disagree  ┆         ┆               ┆               ┆               │
# │ 261         ┆ F2.11    ┆ Somewhat      ┆ No      ┆ 4             ┆ 4             ┆ 4             │
# │             ┆          ┆ Agree         ┆         ┆               ┆               ┆               │
# │ 262         ┆ F2.11    ┆ Somewhat      ┆ No      ┆ 4             ┆ 4             ┆ 4             │
# │             ┆          ┆ Agree         ┆         ┆               ┆               ┆               │
# │ 263         ┆ F2.11    ┆ Somewhat      ┆ No      ┆ 4             ┆ 4             ┆ 4             │
# │             ┆          ┆ Agree         ┆         ┆               ┆               ┆               │
# │ 264         ┆ F2.11    ┆ Somewhat      ┆ No      ┆ 4             ┆ 4             ┆ 4             │
# │             ┆          ┆ Agree         ┆         ┆               ┆               ┆               │
# └─────────────┴──────────┴───────────────┴─────────┴───────────────┴───────────────┴───────────────┘

# %%
stack = stack.with_columns(
    pl.col("Question").str.split(".").list.first().alias("Question Type")
)

# %%
stack
# Out:
# shape: (11_616, 8)
# ┌────────────┬──────────┬────────────┬────────────┬────────────┬───────────┬───────────┬───────────┐
# │ Participan ┆ Question ┆ Response   ┆ Needs      ┆ TempRecode ┆ TempRever ┆ Recoded   ┆ Question  │
# │ t          ┆ ---      ┆ ---        ┆ Reverse    ┆ Value      ┆ seValue   ┆ Value     ┆ Type      │
# │ ---        ┆ str      ┆ str        ┆ ---        ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │ i64        ┆          ┆            ┆ str        ┆ i64        ┆ i64       ┆ i64       ┆ str       │
# ╞════════════╪══════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 1          ┆ F1       ┆ Somewhat   ┆ No         ┆ 4          ┆ 4         ┆ 4         ┆ F1        │
# │            ┆          ┆ Agree      ┆            ┆            ┆           ┆           ┆           │
# │ 2          ┆ F1       ┆ Somewhat   ┆ No         ┆ 4          ┆ 4         ┆ 4         ┆ F1        │
# │            ┆          ┆ Agree      ┆            ┆            ┆           ┆           ┆           │
# │ 3          ┆ F1       ┆ Strongly   ┆ No         ┆ 5          ┆ 5         ┆ 5         ┆ F1        │
# │            ┆          ┆ Agree      ┆            ┆            ┆           ┆           ┆           │
# │ 4          ┆ F1       ┆ Somewhat   ┆ No         ┆ 4          ┆ 4         ┆ 4         ┆ F1        │
# │            ┆          ┆ Agree      ┆            ┆            ┆           ┆           ┆           │
# │ 5          ┆ F1       ┆ Strongly   ┆ No         ┆ 5          ┆ 5         ┆ 5         ┆ F1        │
# │            ┆          ┆ Agree      ┆            ┆            ┆           ┆           ┆           │
# │ …          ┆ …        ┆ …          ┆ …          ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 260        ┆ F2.11    ┆ Neither    ┆ No         ┆ 3          ┆ 3         ┆ 3         ┆ F2        │
# │            ┆          ┆ Agree nor  ┆            ┆            ┆           ┆           ┆           │
# │            ┆          ┆ Disagree   ┆            ┆            ┆           ┆           ┆           │
# │ 261        ┆ F2.11    ┆ Somewhat   ┆ No         ┆ 4          ┆ 4         ┆ 4         ┆ F2        │
# │            ┆          ┆ Agree      ┆            ┆            ┆           ┆           ┆           │
# │ 262        ┆ F2.11    ┆ Somewhat   ┆ No         ┆ 4          ┆ 4         ┆ 4         ┆ F2        │
# │            ┆          ┆ Agree      ┆            ┆            ┆           ┆           ┆           │
# │ 263        ┆ F2.11    ┆ Somewhat   ┆ No         ┆ 4          ┆ 4         ┆ 4         ┆ F2        │
# │            ┆          ┆ Agree      ┆            ┆            ┆           ┆           ┆           │
# │ 264        ┆ F2.11    ┆ Somewhat   ┆ No         ┆ 4          ┆ 4         ┆ 4         ┆ F2        │
# │            ┆          ┆ Agree      ┆            ┆            ┆           ┆           ┆           │
# └────────────┴──────────┴────────────┴────────────┴────────────┴───────────┴───────────┴───────────┘

# %%
summary = (
    stack 
    .with_columns(
        pl.col("Participant").cast(pl.Utf8).str.strip_chars().str.replace_all('"', '').cast(pl.Int64)
    )
    .group_by(["Participant", "Question Type"])
    .agg(pl.col("Recoded Value").sum().alias("Recoded Total"))
    .pivot(index="Participant", on="Question Type", values="Recoded Total")
    .select(["Participant", "F1", "F2", "F3", "F4", "F5", "F6"])
    .sort("Participant")
)

# %%
summary
# Out:
# shape: (264, 7)
# ┌─────────────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ Participant ┆ F1  ┆ F2  ┆ F3  ┆ F4  ┆ F5  ┆ F6  │
# │ ---         ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- │
# │ i64         ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 │
# ╞═════════════╪═════╪═════╪═════╪═════╪═════╪═════╡
# │ 1           ┆ 31  ┆ 48  ┆ 20  ┆ 19  ┆ 28  ┆ 16  │
# │ 2           ┆ 31  ┆ 47  ┆ 19  ┆ 17  ┆ 25  ┆ 14  │
# │ 3           ┆ 36  ┆ 46  ┆ 19  ┆ 18  ┆ 26  ┆ 15  │
# │ 4           ┆ 32  ┆ 54  ┆ 12  ┆ 17  ┆ 26  ┆ 18  │
# │ 5           ┆ 37  ┆ 47  ┆ 22  ┆ 19  ┆ 20  ┆ 17  │
# │ …           ┆ …   ┆ …   ┆ …   ┆ …   ┆ …   ┆ …   │
# │ 260         ┆ 32  ┆ 50  ┆ 22  ┆ 18  ┆ 22  ┆ 14  │
# │ 261         ┆ 31  ┆ 48  ┆ 24  ┆ 17  ┆ 28  ┆ 11  │
# │ 262         ┆ 30  ┆ 47  ┆ 20  ┆ 17  ┆ 21  ┆ 15  │
# │ 263         ┆ 38  ┆ 50  ┆ 20  ┆ 17  ┆ 19  ┆ 15  │
# │ 264         ┆ 33  ┆ 53  ┆ 16  ┆ 17  ┆ 19  ┆ 17  │
# └─────────────┴─────┴─────┴─────┴─────┴─────┴─────┘

# %%
summary.write_csv("data/health_survey_summary.csv")

# %% [markdown]
# # Why use relative addresses?
#
# In this notebook, we will illustrate
#
# 1. That relative addresses for loading data files works, but
# 2. Using absolute addresses for loading data files *will not*.

# %% [markdown]
# ## Problem 1 - Load the `lat_long_example.csv` file using a relative address.
#
# **Tasks.**
# 1. Open a terminal, start `nu`, and navigate to the root menu of your first/primary data repository,
# 2. Use `ls **/*` to get the relative address of `lat_long_example.csv`, and
# 3. Use `polars` to load and inspect these data using this relative path.

# %%
relative_path = " ... Your path here ..."

# %%
(lat_lng_example :=
 pl.read_csv(...)
)

# %% [markdown]
# ## Problem 2 - Load the `lat_long_example.csv` file using a absolute address.
#
# **Tasks.**
# 1. Open a terminal, start `nu`, and navigate to the root menu of *one of your first/primary data repository,
# 2. Use `glob **/*` to get the absolute address of `lat_long_example.csv`, and
# 3. Use `polars` to load and inspect these data.

# %%
absolute_path = " ... Your path here ..."

# %%
(lat_lng_example :=
 pl.read_csv(...)
)

# %% [markdown]
# ## Illustrating the problem with absolute addresses
#
# While the relative address in problem 1 points to the data IN THIS COPY of the repo, the absolute address points to the data in EXACTLY one of the copies of the repository. This becomes a problem if (A) anything changes in that repository, or (B) we are working on a different machine.
#
# **Tasks.** To illustrate why this is a problem, do the following.
#
# 1. From your first/primary repository commit and push this notebook to GitHub,
# 2. Fetch and pull this notebook to another local copy of the repository,
# 3. In your file explorer (Files or Finder), move your first/primary repository into another folder, e.g., make a new folder and drag-and-drop the repo.
# 4. Rerun the cells in each local copy of the repository and document your findings in the WORD document.
